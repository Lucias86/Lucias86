# %% [markdown]
# <a href="https://colab.research.google.com/github/Lucias86/Lucias86/blob/main/Alumna_Lucia_Serafini_Com_4_TPFINAL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #TP FINAL

# %% [markdown]
# **Ejercicio 1**\
# Buscar un dataset (Que no sea los trabajados en clases)
#
# **Ejercicio 2**\
# Realizar una introduccion al dataset de que se trata,definir sus variables (Diccionario de datos)
#
# **Ejercicio 3**\
# Identificar el tipo de variable,decide justificando su respuesta.
#
# **Ejercicio 4**\
# Detectar Valores Ausente  y Valores Atipicos .Decidir si eliminarlos y el por que de la eleccion.
#
# **Ejercicio 5**\
# Realizar un analisis univariado y en base a esos graficos,sacar conclusiones.
#
# **Ejercicio 6**\
# Realizar analisis de matriz corelacion y explicar que variable estan correlacionadas\

# %% [markdown]
# **Para los que entregan en blanco**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Dataframe: https://www.kaggle.com/datasets/kacperrabczewski/every-porsche-911

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

url= '/content/porsche_911.csv'
df = pd.read_csv(url)
df.head(100)
# Out:
#                                                  link      generation   \
# 0   https://www.auto-data.net/en/porsche-911-dakar...  911 Dakar (992)
# 1   https://www.auto-data.net/en/porsche-911-targa...  911 Targa (992)
# 2   https://www.auto-data.net/en/porsche-911-targa...  911 Targa (992)
# 3   https://www.auto-data.net/en/porsche-911-targa...  911 Targa (992)
# 4   https://www.auto-data.net/en/porsche-911-targa...  911 Targa (992)
# ..                                                ...              ...
# 95  https://www.auto-data.net/en/porsche-911-991-c...        911 (991)
# 96  https://www.auto-data.net/en/porsche-911-991-c...        911 (991)
# 97  https://www.auto-data.net/en/porsche-911-991-c...        911 (991)
# 98  https://www.auto-data.net/en/porsche-911-991-c...        911 (991)
# 99  https://www.auto-data.net/en/porsche-911-991-c...        911 (991)
#
#                              engine  start_of_production  \
# ...

# %%
df.shape
# Out:
# (288, 61)

# %% [markdown]
# El data set tiene los datos sobre cada modelo Porsche 911 producido, desde 1964 hasta 2023.
#
# ALGUNAS DE SUS VARIABLES SON DE TIPO:
#
# NOMINAL: generación, tipo de combustible, tipo de cuerpo
#
# DISCRETA: asientos, puertas
#
# CONTINUA: inicio de producción,  capacidad de aceite del motor,  coeficiente de resistencia, velocidad máxima, potencia por litro, distancia entre ejes, fin de producción

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 288 entries, 0 to 287
# Data columns (total 61 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   link                                 288 non-null    object
#  1   generation                           288 non-null    object
#  2   engine                               288 non-null    object
#  3   start_of_production                  288 non-null    int64
#  4   powertrain_architecture              288 non-null    object
#  5   body_type                            288 non-null    object
#  6   seats                                288 non-null    object
#  7   doors                                288 non-null    int64
#  8   fuel_type                            288 non-null    object
#  9   acceleration_0-100km/h               255 non-null    object
#  10  acceleration_0-62mph                 255 non-null    object
# ...

# %%
df.describe()
# Out:
#        start_of_production  doors  maximum_speed  power_per_litre  \
# count           288.000000  288.0     276.000000       286.000000
# mean           2002.145833    2.0     283.659420       105.351399
# std              15.675262    0.0      30.240971        29.707074
# min            1964.000000    2.0     200.000000        55.200000
# 25%            1994.000000    2.0     275.000000        82.850000
# 50%            2007.500000    2.0     289.000000       101.300000
# 75%            2015.000000    2.0     306.000000       128.800000
# max            2023.000000    2.0     340.000000       184.200000
#
#        engine_displacement  number_of_cylinders  cylinder_bore  piston_stroke  \
# count           286.000000                284.0     217.000000     217.000000
# mean           3359.902098                  6.0      95.248848      75.784332
# std             495.127470                  0.0       6.139792       4.053192
# ...

# %%
df.isnull().sum()
# Out:
# link                         0
# generation                   0
# engine                       0
# start_of_production          0
# powertrain_architecture      0
#                           ...
# rear_track                  89
# drag_coefficient           116
# acceleration_0-60mph        42
# end_of_production           35
# coolant                    143
# Length: 61, dtype: int64

# %% [markdown]
# Las variables pista trasera, coeficiente de resistencia, aceleración_0-60 mph,  fin de producción y refrigerante, poseen datos nulos (sin información).

# %%
df_clear=df.dropna()

# %%
df.columns
# Out:
# Index(['link', 'generation ', 'engine', 'start_of_production',
#        'powertrain_architecture', 'body_type', 'seats', 'doors', 'fuel_type',
#        'acceleration_0-100km/h', 'acceleration_0-62mph', 'maximum_speed',
#        'weight-to-power_ratio', 'weight-to-torque_ratio', 'power',
#        'power_per_litre', 'torque', 'engine_layout', 'engine_displacement',
#        'number_of_cylinders', 'engine_configuration', 'cylinder_bore',
#        'piston_stroke', 'number_of_valves_per_cylinder',
#        'fuel_injection_system', 'engine_aspiration', 'kerb_weight',
#        'max_weight', 'max_load', 'fuel_tank_capacity', 'length', 'width',
#        'height', 'wheelbase', 'minimum_turning_diameter',
#        'drivetrain_architecture', 'drive_wheel',
#        'number_of_gears_and_type_of_gearbox', 'front_suspension',
#        'rear_suspension', 'front_brakes', 'rear_brakes', 'assisting_systems',
#        'steering_type', 'power_steering', 'tires_size', 'wheel_rims_size',
# ...

# %% [markdown]
# tiene valores atipicos en "velocidad máxima"

# %%
df.hist('maximum_speed')
# Out:
# array([[<Axes: title={'center': 'maximum_speed'}>]], dtype=object)

# %%
df.boxplot('maximum_speed')
# Out:
# <Axes: >

# %% [markdown]
# La variable "Velocidad máxima" tiene valores atipicos menores a 230km/h

# %%
df.corr()
# Out:
# <ipython-input-7-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                                start_of_production  doors  maximum_speed  \
# start_of_production                       1.000000    NaN       0.897935
# doors                                          NaN    NaN            NaN
# maximum_speed                             0.897935    NaN       1.000000
# power_per_litre                           0.815261    NaN       0.819531
# engine_displacement                       0.570344    NaN       0.645119
# number_of_cylinders                            NaN    NaN            NaN
# cylinder_bore                             0.487130    NaN       0.574335
# piston_stroke                             0.742028    NaN       0.709858
# ...

# %% [markdown]
# Están correlacionadas las variables "Inicio de producción" y "Fin de producción"

# %%
df.hist('start_of_production')

df.hist('end_of_production')
# Out:
# array([[<Axes: title={'center': 'end_of_production'}>]], dtype=object)

# %% [markdown]
# Entre 2005 a 2015 fue la mayor produccion de autos Porsche.
#
# En 1980 fue cuando menos se produjo.
#
# En 2020 se dejaron de producir mucho Porsche.

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_score

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df['start_of_production'], df['end_of_production'])

plt.xlabel('start_of_production')
plt.ylabel('end_of_production')
plt.title('INICIO Y FIN DE PRODUCCIÓN')
plt.show()
print
# Out:
# <function print>

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df['start_of_production'], df['maximum_speed'])

plt.xlabel('start_of_production')
plt.ylabel('maximum_speed')
plt.title('Velocidad por años de PRODUCCIÓN')
plt.show()
print
# Out:
# <function print>

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df['end_of_production'], df['maximum_speed'])

plt.xlabel('end_of_production')
plt.ylabel('maximum_speed')
plt.title('Velocidad por años de PRODUCCIÓN')
plt.show()
print
# Out:
# <function print>

# %% [markdown]
# A medida que pasan los años, se produjeron autos con mayor velocidad máxima.
